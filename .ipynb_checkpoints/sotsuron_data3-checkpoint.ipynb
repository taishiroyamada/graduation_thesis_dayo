# %%
#numpyのインストール
import numpy as np
#pandasのインストール
import pandas as pd
#statistics
import statistics as st
#statsmodelsのインストール
import statsmodels.api as sm
#scikit-learnのインストール
import sklearn.linear_model as sl
#pyplotのインストール
import matplotlib.pyplot as plt
#seabornのインストール
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('data2.csv')
df.shape
#195×19次元
# Out:
# (195, 19)

# %%
df.head(10)
# Out:
#         year  avg_temp  avg_temp1  avg_temp2    sun  sun1  sun2  sun3  \
# 0   2000/1/1       7.3          8          1  144.0     0     8     1
# 1   2000/2/1       5.6          8          1  198.9     0     5     1
# 2   2000/3/1       9.0          8          1  202.7     0     8     1
# 3   2000/4/1      14.0          8          1  173.7     0     8     1
# 4   2000/5/1      19.1          8          1  197.1     0     8     1
# 5   2000/6/1      21.4          8          1  132.6     0     8     1
# 6   2000/7/1      26.4          8          1  228.2     0     8     1
# 7   2000/8/1      27.2          8          1  228.3     0     8     1
# 8   2000/9/1      24.4          8          1  131.4     0     8     1
# 9  2000/10/1      18.1          8          1   92.6     0     8     1
#
#    avg_wind  avg_wind1  avg_wind2  avg_cloud_quantity  avg_cloud_quantity1  \
# 0       3.5          8          1                 6.3                    8
# 1       3.7          8          1                 4.4                    8
# 2       4.2          8          1                 4.9                    8
# 3       3.9          8          1                 6.6                    8
# 4       3.5          8          1                 7.0                    8
# 5       3.5          8          1                 8.5                    8
# 6       3.8          8          1                 6.5                    8
# 7       3.1          8          1                 6.7                    8
# 8       3.2          8          1                 7.4                    8
# 9       3.0          8          1                 8.2                    8
#
#    avg_cloud_quantity2  rain_sum  rain_sum1  rain_sum2  rain_sum3     Year
# 0                    1      76.5          0          8          1  #VALUE!
# 1                    1       3.0          0          8          1      NaN
# 2                    1     114.0          0          8          1      NaN
# 3                    1     117.5          0          8          1      NaN
# 4                    1      74.5          0          8          1      NaN
# 5                    1     267.0          0          8          1      NaN
# 6                    1     223.5          0          8          1      NaN
# 7                    1      95.5          0          8          1      NaN
# 8                    1     309.5          0          8          1      NaN
# 9                    1     141.0          0          8          1      NaN

# %%
w_data = df.loc[:,['year','avg_temp','sun','avg_wind','rain_sum','avg_cloud_quantity']]
#年月ごとのグラフ化
m_data = w_data.groupby('year').mean()
v_data = w_data.groupby('year').var()

# %%
plt.style.use('ggplot') 
m_data.plot()

# %%
sun_data = m_data.loc[:,['year','sun']]
sun_data.plot()

# %%
wind_data = m_data.loc[:,['year','avg_wind']]
wind_data.plot()

# %%
rain_data = m_data.loc[:,['year','rain_sum']]
rain_data.plot()

# %%
rain_data = m_data.loc[:,['year','avg_cloud_quantity']]
rain_data.plot()

# %%
rain_data = m_data.loc[:,['year','rain_sum']]
rain_data.plot()

# %%
sns.pairplot(m_data)

# %%
correlation_matrix = np.corrcoef(m_data.transpose())

# %%
names = ['avg_temp','sun','avg_wind','rain_sum','cloud_quantity']

# %%
sns.heatmap(correlation_matrix, annot=True, xticklabels=names,yticklabels=names)

# %%
w_data = w_data.drop(['avg_cloud_quantity'],axis=1)

# %%
w_data['year'] = w_data['year'].str.split('/', expand=True)

# %%
var_temp = w_data.groupby('year')['avg_temp'].agg(['std'])
var_temp.head()
# Out:
#            std
# year
# 2000  7.689485
# 2001  7.786974
# 2002  7.339118
# 2003  7.139752
# 2004  7.423591

# %%
sum_all = w_data.groupby('year')['avg_temp','rain_sum','sun','avg_wind'].agg(['sum'])
sum_all.head()
# Out:
#      avg_temp rain_sum     sun avg_wind
#           sum      sum     sum      sum
# year
# 2000    193.8   1557.5  2024.3     42.4
# 2001    190.4   1630.5  2063.6     41.8
# 2002    193.7   1638.0  2073.9     44.0
# 2003    187.0   2132.5  1794.3     43.2
# 2004    202.4   1932.0  2247.9     44.9

# %%
cd_df = pd.concat([var_temp,sum_all], axis=1)
cd_df.head()
# Out:
#            std  (avg_temp, sum)  (rain_sum, sum)  (sun, sum)  (avg_wind, sum)
# year
# 2000  7.689485            193.8           1557.5      2024.3             42.4
# 2001  7.786974            190.4           1630.5      2063.6             41.8
# 2002  7.339118            193.7           1638.0      2073.9             44.0
# 2003  7.139752            187.0           2132.5      1794.3             43.2
# 2004  7.423591            202.4           1932.0      2247.9             44.9

# %%
cd_value = cd_df.values
cd_pd = pd.DataFrame(cd_value)
cd_pd.head()
# Out:
#           0      1       2       3     4
# 0  7.689485  193.8  1557.5  2024.3  42.4
# 1  7.786974  190.4  1630.5  2063.6  41.8
# 2  7.339118  193.7  1638.0  2073.9  44.0
# 3  7.139752  187.0  2132.5  1794.3  43.2
# 4  7.423591  202.4  1932.0  2247.9  44.9

# %%
cd_pd.columns = ['var_temp','sum_temp','sum_sun','sum_wind','sum_rain']
cd_pd.head()
# Out:
#    var_temp  sum_temp  sum_sun  sum_wind  sum_rain
# 0  7.689485     193.8   1557.5    2024.3      42.4
# 1  7.786974     190.4   1630.5    2063.6      41.8
# 2  7.339118     193.7   1638.0    2073.9      44.0
# 3  7.139752     187.0   2132.5    1794.3      43.2
# 4  7.423591     202.4   1932.0    2247.9      44.9

# %%
cd_henko = cd_pd.drop(0,axis=0)

# %%
cd_henko.head()
# Out:
#    var_temp  sum_temp  sum_sun  sum_wind  sum_rain
# 1  7.786974     190.4   1630.5    2063.6      41.8
# 2  7.339118     193.7   1638.0    2073.9      44.0
# 3  7.139752     187.0   2132.5    1794.3      43.2
# 4  7.423591     202.4   1932.0    2247.9      44.9
# 5  7.816004     189.5   1411.0    2045.1      40.5

# %%
econ = pd.read_csv('econ2.csv',delimiter=',')

# %%
econ.head()
# Out:
#    year  money
# 0  2001   35.7
# 1  2002   37.9
# 2  2003   38.0
# 3  2004   36.3
# 4  2005   35.0

# %%
yt_data = pd.concat([econ,cd_henko], axis=1)
yt_data.head()
# Out:
#      year  money  var_temp  sum_temp  sum_sun  sum_wind  sum_rain
# 0  2001.0   35.7       NaN       NaN      NaN       NaN       NaN
# 1  2002.0   37.9  7.786974     190.4   1630.5    2063.6      41.8
# 2  2003.0   38.0  7.339118     193.7   1638.0    2073.9      44.0
# 3  2004.0   36.3  7.139752     187.0   2132.5    1794.3      43.2
# 4  2005.0   35.0  7.423591     202.4   1932.0    2247.9      44.9
